# %%
import os
import numpy as np
import scipy
from scipy.signal import butter, filtfilt, find_peaks

# 1. Force PyTorch to fully initialize first to prevent circular |imports
import torch
import torch.fx  
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

# 2. Now import Ray and its training submodules safely
import ray
import ray.train.torch
from ray.train import ScalingConfig, Checkpoint
from ray.train.torch import TorchTrainer

# %%
ray.init(num_cpus=8, ignore_reinit_error=True)
BASE_PATH = "/expanse/lustre/projects/uci157/ysuh2"
DATA_DIR = "data/stead_version4/"

ds = ray.data.read_parquet(BASE_PATH+"/"+DATA_DIR,shuffle="files").limit(80_000)

def filter_earthquakes(batch):
    return batch[batch["trace_category"] == "earthquake_local"]
    

def preprocess_seismic_batch(batch: dict) -> dict:
    # 1. Directly grab arrays from batch
    filtered_N = batch["waveform_N"]
    filtered_Z = batch["waveform_Z"]
    filtered_E = batch["waveform_E"]

    num_rows = len(filtered_N)
    if num_rows == 0:
        return {"x": [], "y": []}

    # Set known fixed sequence length
    seq_len = 6000

    # 2. Optimized Stack: Vectorized casting directly into float32 matrices
    # (Removes the row-by-row Python loop entirely)
    N_2d = np.array(list(filtered_N), dtype=np.float32)
    Z_2d = np.array(list(filtered_Z), dtype=np.float32)
    E_2d = np.array(list(filtered_E), dtype=np.float32)

    # Now stack into the proper 3D numeric volume: Shape (Batch, 3, Seq_Len)
    X = np.stack([N_2d, Z_2d, E_2d], axis=1)

    # --- FOOLPROOF SCALAR CONVERSION FUNCTION FOR ARRIVALS ---
    def safe_extract_scalar(val):
        try:
            while hasattr(val, "__len__") and not isinstance(val, (str, bytes)):
                if len(val) == 0:
                    return -1.0
                val = val[0]
            return float(val)
        except (ValueError, TypeError):
            return -1.0

    raw_p_unwrapped = [
        safe_extract_scalar(p) for p in batch["p_arrival_sample"]
    ]
    raw_s_unwrapped = [
        safe_extract_scalar(s) for s in batch["s_arrival_sample"]
    ]

    filtered_p = np.asarray(raw_p_unwrapped, dtype=np.float64).astype(np.int64)
    filtered_s = np.asarray(raw_s_unwrapped, dtype=np.float64).astype(np.int64)

    # 3. Apply Bandpass Filter & Normalization
    sampling_rate = 100.0
    nyq = 0.5 * sampling_rate
    b, a = butter(4, [1.0 / nyq, 20.0 / nyq], btype="band")

    X_proc = np.zeros_like(X)
    for idx in range(X.shape[0]):
        for ch in range(3):
            filtered_channel = filtfilt(b, a, X[idx, ch])
            mean = np.mean(filtered_channel)
            std = np.std(filtered_channel)
            X_proc[idx, ch] = (filtered_channel - mean) / (std + 1e-6)

    # 4. Vectorized Label Generation
    sigma = 10.0
    x_ticks = np.arange(seq_len)

    p_diff = x_ticks[None, :] - filtered_p[:, None]
    s_diff = x_ticks[None, :] - filtered_s[:, None]

    Y = np.zeros((X.shape[0], 3, seq_len), dtype=np.float32)

    Y[:, 0, :] = np.exp(-0.5 * (p_diff / sigma) ** 2)
    Y[:, 1, :] = np.exp(-0.5 * (s_diff / sigma) ** 2)

    # Out of timeline bounds validation check
    for idx in range(X.shape[0]):
        if not (0 <= filtered_p[idx] < seq_len):
            Y[idx, 0, :] = 0.0
        if not (0 <= filtered_s[idx] < seq_len):
            Y[idx, 1, :] = 0.0

    Y[:, 2, :] = 1.0 - np.maximum(Y[:, 0, :], Y[:, 1, :])

    y_sum = np.sum(Y, axis=1, keepdims=True)
    Y = Y / np.maximum(y_sum, 1e-8)

    return {"x": X_proc, "y": Y}

# Select, Map, Shuffle, and Split
waveform_ds = ds.select_columns(["waveform_N", "waveform_Z", "waveform_E", "s_arrival_sample", "p_arrival_sample","trace_category"])
waveform_ds = waveform_ds.map_batches(filter_earthquakes, batch_format="pandas")
prepared_ds = waveform_ds.map_batches(preprocess_seismic_batch, batch_format="numpy")
train_ds, val_ds, test_ds = prepared_ds.split_proportionately([0.7, 0.15])
# Out:
# 2026-06-01 18:33:00,323	INFO worker.py:1843 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8265
# Metadata Fetch Progress 0:   0%|          | 0.00/140 [00:00<?, ? task/s]
# Parquet Files Sample 0:   0%|          | 0.00/8.00 [00:00<?, ? file/s]
# 2026-06-01 18:33:57,386	INFO streaming_executor.py:108 -- Starting execution of Dataset. Full logs are in /tmp/ray/ray/session_2026-06-01_18-32-56_313471_690333/logs/ray-data
# 2026-06-01 18:33:57,387	INFO streaming_executor.py:109 -- Execution plan of Dataset: InputDataBuffer[Input] -> TaskPoolMapOperator[ReadParquet] -> LimitOperator[limit=80000] -> TaskPoolMapOperator[Project->MapBatches(filter_earthquakes)->MapBatches(preprocess_seismic_batch)] -> AggregateNumRows[AggregateNumRows]
# Running 0: 0.00 row [00:00, ? row/s]
# - ReadParquet 1: 0.00 row [00:00, ? row/s]
# - limit=80000 2: 0.00 row [00:00, ? row/s]
# - Project->MapBatches(filter_earthquakes)->MapBatches(preprocess_seismic_batch) 3: 0.00 row [00:00, ? row/s]
# - AggregateNumRows 4: 0.00 row [00:00, ? row/s]
# 2026-06-01 18:33:57,837	WARNING progress_bar.py:120 -- Truncating long operator name to 100 characters. To disable this behavior, set `ray.data.DataContext.get_current().DEFAULT_ENABLE_PROGRESS_BAR_NAME_TRUNCATION = False`.
# (Project->MapBatches(filter_earthquakes)->MapBatches(preprocess_seismic_batch) pid=705389) Error calculating size for column 'waveform_N': cannot call `vectorize` on size 0 inputs unless `otypes` is set
# (Project->MapBatches(filter_earthquakes)->MapBatches(preprocess_seismic_batch) pid=705389) Error calculating size for column 'waveform_Z': cannot call `vectorize` on size 0 inputs unless `otypes` is set
# (Project->MapBatches(filter_earthquakes)->MapBatches(preprocess_seismic_batch) pid=705389) Error calculating size for column 'waveform_E': cannot call `vectorize` on size 0 inputs unless `otypes` is set
# (Project->MapBatches(filter_earthquakes)->MapBatches(preprocess_seismic_batch) pid=705389) Error calculating size for column 's_arrival_sample': cannot call `vectorize` on size 0 inputs unless `otypes` is set
# (Project->MapBatches(filter_earthquakes)->MapBatches(preprocess_seismic_batch) pid=705389) Error calculating size for column 'p_arrival_sample': cannot call `vectorize` on size 0 inputs unless `otypes` is set
# (Project->MapBatches(filter_earthquakes)->MapBatches(preprocess_seismic_batch) pid=705389) Error calculating size for column 'trace_category': cannot call `vectorize` on size 0 inputs unless `otypes` is set
# 2026-06-01 18:34:18,706	INFO streaming_executor.py:108 -- Starting execution of Dataset. Full logs are in /tmp/ray/ray/session_2026-06-01_18-32-56_313471_690333/logs/ray-data
# 2026-06-01 18:34:18,707	INFO streaming_executor.py:109 -- Execution plan of Dataset: InputDataBuffer[Input] -> TaskPoolMapOperator[ReadParquet] -> LimitOperator[limit=80000] -> TaskPoolMapOperator[Project->MapBatches(filter_earthquakes)->MapBatches(preprocess_seismic_batch)]
# Running 0: 0.00 row [00:00, ? row/s]
# - ReadParquet 1: 0.00 row [00:00, ? row/s]
# - limit=80000 2: 0.00 row [00:00, ? row/s]
# - Project->MapBatches(filter_earthquakes)->MapBatches(preprocess_seismic_batch) 3: 0.00 row [00:00, ? row/s]
# (Project->MapBatches(filter_earthquakes)->MapBatches(preprocess_seismic_batch) pid=705747) Error calculating size for column 'waveform_N': cannot call `vectorize` on size 0 inputs unless `otypes` is set [repeated 3x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
# (Project->MapBatches(filter_earthquakes)->MapBatches(preprocess_seismic_batch) pid=705747) Error calculating size for column 'waveform_Z': cannot call `vectorize` on size 0 inputs unless `otypes` is set [repeated 3x across cluster]
# (Project->MapBatches(filter_earthquakes)->MapBatches(preprocess_seismic_batch) pid=705747) Error calculating size for column 'waveform_E': cannot call `vectorize` on size 0 inputs unless `otypes` is set [repeated 3x across cluster]
# (Project->MapBatches(filter_earthquakes)->MapBatches(preprocess_seismic_batch) pid=705747) Error calculating size for column 's_arrival_sample': cannot call `vectorize` on size 0 inputs unless `otypes` is set [repeated 3x across cluster]
# (Project->MapBatches(filter_earthquakes)->MapBatches(preprocess_seismic_batch) pid=705747) Error calculating size for column 'p_arrival_sample': cannot call `vectorize` on size 0 inputs unless `otypes` is set [repeated 3x across cluster]
# (Project->MapBatches(filter_earthquakes)->MapBatches(preprocess_seismic_batch) pid=705747) Error calculating size for column 'trace_category': cannot call `vectorize` on size 0 inputs unless `otypes` is set [repeated 3x across cluster]
# (Project->MapBatches(filter_earthquakes)->MapBatches(preprocess_seismic_batch) pid=705391) Error calculating size for column 'waveform_N': cannot call `vectorize` on size 0 inputs unless `otypes` is set [repeated 6x across cluster]
# (Project->MapBatches(filter_earthquakes)->MapBatches(preprocess_seismic_batch) pid=705391) Error calculating size for column 'waveform_Z': cannot call `vectorize` on size 0 inputs unless `otypes` is set [repeated 6x across cluster]
# (Project->MapBatches(filter_earthquakes)->MapBatches(preprocess_seismic_batch) pid=705391) Error calculating size for column 'waveform_E': cannot call `vectorize` on size 0 inputs unless `otypes` is set [repeated 6x across cluster]
# (Project->MapBatches(filter_earthquakes)->MapBatches(preprocess_seismic_batch) pid=705391) Error calculating size for column 's_arrival_sample': cannot call `vectorize` on size 0 inputs unless `otypes` is set [repeated 6x across cluster]
# (Project->MapBatches(filter_earthquakes)->MapBatches(preprocess_seismic_batch) pid=705391) Error calculating size for column 'p_arrival_sample': cannot call `vectorize` on size 0 inputs unless `otypes` is set [repeated 6x across cluster]
# (Project->MapBatches(filter_earthquakes)->MapBatches(preprocess_seismic_batch) pid=705391) Error calculating size for column 'trace_category': cannot call `vectorize` on size 0 inputs unless `otypes` is set [repeated 6x across cluster]

# %%
# ==========================================
# 1. PREPROCESSING & LABEL GENERATION
# ==========================================
def gaussian_label(length, center, sigma=10):
    x = np.arange(length)
    return np.exp(-0.5 * ((x - center) / sigma) ** 2)


def make_phase_labels(length, p_index=None, s_index=None, sigma=10):
    y = np.zeros((3, length), dtype=np.float32)

    if p_index is not None and 0 <= p_index < length:
        y[0] = gaussian_label(length, p_index, sigma)

    if s_index is not None and 0 <= s_index < length:
        y[1] = gaussian_label(length, s_index, sigma)

    phase_max = np.maximum(y[0], y[1])
    y[2] = 1.0 - phase_max

    y_sum = np.sum(y, axis=0, keepdims=True)
    y = y / np.maximum(y_sum, 1e-8)

    return y


def normalize_waveform(x):
    x = x.astype(np.float32)
    for i in range(x.shape[0]):
        mean = np.mean(x[i])
        std = np.std(x[i])
        x[i] = (x[i] - mean) / (std + 1e-6)
    return x


def bandpass_filter(x, sampling_rate, low=1.0, high=20.0, order=4):
    nyq = 0.5 * sampling_rate
    low_norm = low / nyq
    high_norm = high / nyq

    b, a = butter(order, [low_norm, high_norm], btype="band")

    filtered = np.zeros_like(x, dtype=np.float32)
    for i in range(x.shape[0]):
        filtered[i] = filtfilt(b, a, x[i]).astype(np.float32)

    return filtered


# ==========================================
# 2. PYTORCH DATASET
# ==========================================
class PhasePickingDataset(Dataset):
    def __init__(self, records, label_sigma=10, apply_filter=False, sampling_rate=100):
        self.records = records
        self.label_sigma = label_sigma
        self.apply_filter = apply_filter
        self.sampling_rate = sampling_rate

    def __len__(self):
        return len(self.records)

    def __getitem__(self, idx):
        record = self.records[idx]
        x = record["waveform"]  

        if self.apply_filter:
            x = bandpass_filter(x, self.sampling_rate)

        x = normalize_waveform(x)
        length = x.shape[1]
        
        y = make_phase_labels(
            length=length,
            p_index=record.get("p_index"),
            s_index=record.get("s_index"),
            sigma=self.label_sigma,
        )

        return {
            "x": torch.tensor(x, dtype=torch.float32),
            "y": torch.tensor(y, dtype=torch.float32),
        }


# ==========================================
# 3. PHASENET MODEL ARCHITECTURE
# ==========================================
class ConvBlock(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.block = nn.Sequential(
            nn.Conv1d(in_channels, out_channels, kernel_size=7, padding=3),
            nn.BatchNorm1d(out_channels),
            nn.ReLU(inplace=True),
            nn.Conv1d(out_channels, out_channels, kernel_size=7, padding=3),
            nn.BatchNorm1d(out_channels),
            nn.ReLU(inplace=True),
        )

    def forward(self, x):
        return self.block(x)


class PhaseNetLike(nn.Module):
    def __init__(self, in_channels=3, out_channels=3):
        super().__init__()
        self.enc1 = ConvBlock(in_channels, 32)
        self.enc2 = ConvBlock(32, 64)
        self.enc3 = ConvBlock(64, 128)
        self.enc4 = ConvBlock(128, 256)

        self.pool = nn.MaxPool1d(2)
        self.bottleneck = ConvBlock(256, 512)

        self.up4 = nn.ConvTranspose1d(512, 256, kernel_size=2, stride=2)
        self.dec4 = ConvBlock(512, 256)

        self.up3 = nn.ConvTranspose1d(256, 128, kernel_size=2, stride=2)
        self.dec3 = ConvBlock(256, 128)

        self.up2 = nn.ConvTranspose1d(128, 64, kernel_size=2, stride=2)
        self.dec2 = ConvBlock(128, 64)

        self.up1 = nn.ConvTranspose1d(64, 32, kernel_size=2, stride=2)
        self.dec1 = ConvBlock(64, 32)

        self.out = nn.Conv1d(32, out_channels, kernel_size=1)

    def crop_or_pad(self, x, target_length):
        current_length = x.shape[-1]
        if current_length == target_length:
            return x
        if current_length > target_length:
            return x[..., :target_length]
        pad_amount = target_length - current_length
        return F.pad(x, (0, pad_amount))

    def forward(self, x):
        e1 = self.enc1(x)
        e2 = self.enc2(self.pool(e1))
        e3 = self.enc3(self.pool(e2))
        e4 = self.enc4(self.pool(e3))

        b = self.bottleneck(self.pool(e4))

        d4 = self.up4(b)
        d4 = self.crop_or_pad(d4, e4.shape[-1])
        d4 = torch.cat([d4, e4], dim=1)
        d4 = self.dec4(d4)

        d3 = self.up3(d4)
        d3 = self.crop_or_pad(d3, e3.shape[-1])
        d3 = torch.cat([d3, e3], dim=1)
        d3 = self.dec3(d3)

        d2 = self.up2(d3)
        d2 = self.crop_or_pad(d2, e2.shape[-1])
        d2 = torch.cat([d2, e2], dim=1)
        d2 = self.dec2(d2)

        d1 = self.up1(d2)
        d1 = self.crop_or_pad(d1, e1.shape[-1])
        d1 = torch.cat([d1, e1], dim=1)
        d1 = self.dec1(d1)

        logits = self.out(d1)
        return F.softmax(logits, dim=1)


# ==========================================
# 4. PARALLEL RAY TRAINING INFRASTRUCTURE
# ==========================================
def soft_cross_entropy(pred, target, eps=1e-8):
    return -(target * torch.log(pred + eps)).sum(dim=1).mean()

def train_func(config):
    lr = config.get("lr", 1e-3)
    batch_size = config.get("batch_size", 16)
    epochs = config.get("epochs", 5)  

    model = PhaseNetLike()
    model = ray.train.torch.prepare_model(model)  
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)

    # Grab the distributed shard assigned exclusively to this training worker node
    train_data_shard = ray.train.get_dataset_shard("train")

    for epoch in range(epochs):
        model.train()
        total_loss = 0.0
        batch_count = 0

        # Efficiently stream batches out of Ray's distributed storage system
        train_loader = train_data_shard.iter_torch_batches(batch_size=batch_size, local_shuffle_buffer_size=250)
        
        for batch in train_loader:
            x = batch["x"] # Automatically converted to torch.Tensor
            y = batch["y"]

            pred = model(x)
            loss = soft_cross_entropy(pred, y)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            total_loss += loss.item()
            batch_count += 1

        avg_loss = total_loss / max(batch_count, 1)

        # Handle logging and custom file saving on Rank 0
        if ray.train.get_context().get_world_rank() == 0:
            print(f"Epoch {epoch + 1}: loss = {avg_loss:.5f}")
            
            output_dir = os.environ.get('HOME') + "/ysuh2/model_checkpoints"
            os.makedirs(output_dir, exist_ok=True)
            
            checkpoint_filepath = os.path.join(output_dir, f"phasenet_epoch_{epoch + 1}.pt")
            torch.save(model.module.state_dict(), checkpoint_filepath)
            
            ray.train.report(
                metrics={"loss": avg_loss},
                checkpoint=Checkpoint.from_directory(output_dir)
            )
        else:
            ray.train.report(metrics={"loss": avg_loss})

# ==========================================
# 5. EXECUTION & INFERENCE ENGINE
# ==========================================
def pick_arrivals(probabilities, sampling_rate, window_start_time=0.0):
    p_prob = probabilities[0]
    s_prob = probabilities[1]

    p_index = int(np.argmax(p_prob))
    s_index = int(np.argmax(s_prob))

    p_time = window_start_time + p_index / sampling_rate
    s_time = window_start_time + s_index / sampling_rate

    return p_time, s_time, p_index, s_index


if __name__ == "__main__":
    if not ray.is_initialized():
        ray.init(num_cpus=8, ignore_reinit_error=True)

    scaling_config = ScalingConfig(num_workers=4, use_gpu=False) # Change to use_gpu=True if nodes have GPUs

    trainer = TorchTrainer(
        train_loop_per_worker=train_func,
        train_loop_config={"lr": 1e-3, "batch_size": 16, "epochs": 5},
        scaling_config=scaling_config,
        datasets={"train": train_ds} # Feed the Ray dataset split straight into the trainer!
    )

    print("--- Starting Parallel Distributed Ray Training Loop ---")
    result = trainer.fit()
    print("--- Training Execution Finished successfully! ---")

    # --- Run Inference using a real sample from your Test Split ---
    print("\n--- Running Inference Setup ---")
    eval_model = PhaseNetLike()
    
    final_epoch = 5
    best_checkpoint = result.checkpoint
    
    if best_checkpoint:
        with best_checkpoint.as_directory() as checkpoint_dir:
            local_checkpoint_path = os.path.join(checkpoint_dir, f"phasenet_epoch_{final_epoch}.pt")
            eval_model.load_state_dict(torch.load(local_checkpoint_path))
    else:
        raise RuntimeError("No checkpoint was found in the training result!")

    eval_model.eval()

    # Clean Ray native batch extraction
    test_sample = next(iter(test_ds.iter_batches(batch_size=1, batch_format="numpy")))
    real_x = test_sample["x"]  # Shape: (1, 3, sequence_length)

    with torch.no_grad():
        x_tensor = torch.tensor(real_x, dtype=torch.float32)
        pred_out = eval_model(x_tensor)[0].cpu().numpy() 

    # Find predictions using your picking logic
    p_time, s_time, p_idx, s_idx = pick_arrivals(pred_out, sampling_rate=100.0)

    print(f"Predicted P Wave Arrival Time: {p_time:.2f}s (Index: {p_idx})")
    print(f"Predicted S Wave Arrival Time: {s_time:.2f}s (Index: {s_idx})")

    print("\n--- Running Full Test Dataset Evaluation ---")
    
    total_test_loss = 0.0
    test_batch_count = 0

    test_loader = test_ds.iter_batches(batch_size=64, batch_format="numpy")

    with torch.no_grad():
        for batch in test_loader:
            x_tensor = torch.tensor(batch["x"], dtype=torch.float32)
            y_tensor = torch.tensor(batch["y"], dtype=torch.float32)

            pred = eval_model(x_tensor)
            loss = soft_cross_entropy(pred, y_tensor)
            
            total_test_loss += loss.item()
            test_batch_count += 1

    avg_test_loss = total_test_loss / max(test_batch_count, 1)
    final_train_loss = result.metrics["loss"]
    print("--------------------------------------------------")
    print(f"Final Training Loss: {final_train_loss:.5f}")
    print(f"Final Average Test Loss: {avg_test_loss:.5f}")
    print(f"Evaluated on {test_batch_count * 64} total samples.")
    print("--------------------------------------------------")
# Out:
# 2026-05-31 23:27:30,011	INFO tune.py:616 -- [output] This uses the legacy output and progress reporter, as Jupyter notebooks are not supported by the new engine, yet. For more information, please see https://github.com/ray-project/ray/issues/36949
# --- Starting Parallel Distributed Ray Training Loop ---
# == Status ==
# Current time: 2026-05-31 23:27:30 (running for 00:00:00.11)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 PENDING)
#
#
# == Status ==
# Current time: 2026-05-31 23:27:35 (running for 00:00:05.12)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 PENDING)
#
#
# == Status ==
# Current time: 2026-05-31 23:27:40 (running for 00:00:10.18)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
# (TorchTrainer pid=1788803) Started distributed worker processes:
# (TorchTrainer pid=1788803) - (node_id=f1deb261173f40feb81308f3b58067254a50d38ecaa65ee4bcd3b876, ip=198.202.102.216, pid=1788904) world_rank=0, local_rank=0, node_rank=0
# (TorchTrainer pid=1788803) - (node_id=f1deb261173f40feb81308f3b58067254a50d38ecaa65ee4bcd3b876, ip=198.202.102.216, pid=1788906) world_rank=1, local_rank=1, node_rank=0
# (TorchTrainer pid=1788803) - (node_id=f1deb261173f40feb81308f3b58067254a50d38ecaa65ee4bcd3b876, ip=198.202.102.216, pid=1788905) world_rank=2, local_rank=2, node_rank=0
# (TorchTrainer pid=1788803) - (node_id=f1deb261173f40feb81308f3b58067254a50d38ecaa65ee4bcd3b876, ip=198.202.102.216, pid=1788903) world_rank=3, local_rank=3, node_rank=0
# (RayTrainWorker pid=1788904) Setting up process group for: env:// [rank=0, world_size=4]
# (RayTrainWorker pid=1788905) [Gloo] Rank 2 is connected to 3 peer ranks. Expected number of connected peer ranks is : 3
# (RayTrainWorker pid=1788904) Moving model to device: cpu
# (RayTrainWorker pid=1788904) Wrapping provided model in DistributedDataParallel.
# (pid=1789287) Running 0: 0.00 row [00:00, ? row/s]
# (pid=1789287) - split(4, equal=True) 1: 0.00 row [00:00, ? row/s]
# (SplitCoordinator pid=1789287) Starting execution of Dataset. Full logs are in /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/logs/ray-data
# (SplitCoordinator pid=1789287) Execution plan of Dataset: InputDataBuffer[Input] -> OutputSplitter[split(4, equal=True)]
# == Status ==
# Current time: 2026-05-31 23:27:45 (running for 00:00:15.20)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:27:50 (running for 00:00:20.23)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:27:55 (running for 00:00:25.26)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:28:00 (running for 00:00:30.28)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:28:05 (running for 00:00:35.31)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:28:10 (running for 00:00:40.33)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:28:15 (running for 00:00:45.35)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:28:20 (running for 00:00:50.38)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:28:25 (running for 00:00:55.40)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:28:30 (running for 00:01:00.42)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:28:35 (running for 00:01:05.45)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:28:40 (running for 00:01:10.47)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:28:45 (running for 00:01:15.49)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:28:50 (running for 00:01:20.52)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:28:55 (running for 00:01:25.54)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:29:00 (running for 00:01:30.57)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:29:05 (running for 00:01:35.59)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:29:10 (running for 00:01:40.61)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:29:15 (running for 00:01:45.64)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:29:20 (running for 00:01:50.66)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:29:25 (running for 00:01:55.68)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:29:30 (running for 00:02:00.71)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:29:35 (running for 00:02:05.73)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:29:40 (running for 00:02:10.75)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:29:45 (running for 00:02:15.77)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:29:50 (running for 00:02:20.80)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:29:55 (running for 00:02:25.82)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:30:00 (running for 00:02:30.85)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:30:05 (running for 00:02:35.87)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:30:10 (running for 00:02:40.89)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:30:15 (running for 00:02:45.92)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:30:20 (running for 00:02:50.94)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:30:25 (running for 00:02:55.96)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:30:31 (running for 00:03:00.99)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:30:36 (running for 00:03:06.01)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:30:41 (running for 00:03:11.03)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:30:46 (running for 00:03:16.05)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:30:51 (running for 00:03:21.08)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:30:56 (running for 00:03:26.10)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:31:01 (running for 00:03:31.13)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:31:06 (running for 00:03:36.15)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:31:11 (running for 00:03:41.18)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:31:16 (running for 00:03:46.20)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:31:21 (running for 00:03:51.23)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:31:26 (running for 00:03:56.25)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:31:31 (running for 00:04:01.27)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:31:36 (running for 00:04:06.30)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:31:41 (running for 00:04:11.32)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:31:46 (running for 00:04:16.34)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# (RayTrainWorker pid=1788903) [Gloo] Rank 3 is connected to 3 peer ranks. Expected number of connected peer ranks is : 3 [repeated 3x across cluster]
# == Status ==
# Current time: 2026-05-31 23:31:51 (running for 00:04:21.37)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:31:56 (running for 00:04:26.39)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:32:01 (running for 00:04:31.41)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:32:06 (running for 00:04:36.43)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:32:11 (running for 00:04:41.46)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:32:16 (running for 00:04:46.48)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:32:21 (running for 00:04:51.51)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:32:26 (running for 00:04:56.53)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:32:31 (running for 00:05:01.55)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:32:36 (running for 00:05:06.57)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:32:41 (running for 00:05:11.60)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:32:46 (running for 00:05:16.62)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:32:51 (running for 00:05:21.64)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:32:56 (running for 00:05:26.66)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:33:01 (running for 00:05:31.69)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:33:06 (running for 00:05:36.71)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:33:11 (running for 00:05:41.73)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:33:16 (running for 00:05:46.76)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:33:21 (running for 00:05:51.78)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:33:26 (running for 00:05:56.80)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:33:31 (running for 00:06:01.83)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:33:36 (running for 00:06:06.85)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:33:41 (running for 00:06:11.88)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:33:46 (running for 00:06:16.90)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:33:51 (running for 00:06:21.92)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:33:56 (running for 00:06:26.95)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:34:01 (running for 00:06:31.97)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:34:07 (running for 00:06:36.99)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:34:12 (running for 00:06:42.02)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:34:17 (running for 00:06:47.04)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:34:22 (running for 00:06:52.06)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:34:27 (running for 00:06:57.08)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:34:32 (running for 00:07:02.11)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:34:37 (running for 00:07:07.14)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:34:42 (running for 00:07:12.16)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:34:47 (running for 00:07:17.18)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:34:52 (running for 00:07:22.21)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:34:57 (running for 00:07:27.23)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:35:02 (running for 00:07:32.25)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:35:07 (running for 00:07:37.28)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:35:12 (running for 00:07:42.30)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:35:17 (running for 00:07:47.32)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:35:22 (running for 00:07:52.34)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:35:27 (running for 00:07:57.37)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:35:32 (running for 00:08:02.40)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:35:37 (running for 00:08:07.42)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:35:42 (running for 00:08:12.45)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:35:47 (running for 00:08:17.47)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:35:52 (running for 00:08:22.49)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:35:57 (running for 00:08:27.52)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:36:02 (running for 00:08:32.54)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:36:07 (running for 00:08:37.56)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:36:12 (running for 00:08:42.59)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:36:17 (running for 00:08:47.61)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:36:22 (running for 00:08:52.63)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:36:27 (running for 00:08:57.65)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:36:32 (running for 00:09:02.68)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:36:37 (running for 00:09:07.70)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:36:42 (running for 00:09:12.72)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:36:47 (running for 00:09:17.75)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:36:52 (running for 00:09:22.77)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:36:57 (running for 00:09:27.80)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:37:02 (running for 00:09:32.82)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:37:07 (running for 00:09:37.84)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:37:12 (running for 00:09:42.87)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:37:17 (running for 00:09:47.89)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:37:22 (running for 00:09:52.92)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:37:27 (running for 00:09:57.94)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:37:32 (running for 00:10:02.96)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:37:38 (running for 00:10:07.98)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:37:43 (running for 00:10:13.01)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:37:48 (running for 00:10:18.03)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:37:53 (running for 00:10:23.05)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:37:58 (running for 00:10:28.08)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:38:03 (running for 00:10:33.10)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:38:08 (running for 00:10:38.12)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:38:13 (running for 00:10:43.15)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:38:18 (running for 00:10:48.17)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:38:23 (running for 00:10:53.19)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:38:28 (running for 00:10:58.21)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:38:33 (running for 00:11:03.24)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:38:38 (running for 00:11:08.26)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:38:43 (running for 00:11:13.28)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:38:48 (running for 00:11:18.30)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-05-31 23:38:53 (running for 00:11:23.33)
# ...
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-06-01 04:17:42 (running for 04:50:12.82)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-06-01 04:17:47 (running for 04:50:17.84)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-06-01 04:17:52 (running for 04:50:22.86)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-06-01 04:17:57 (running for 04:50:27.89)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-06-01 04:18:02 (running for 04:50:32.91)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-06-01 04:18:07 (running for 04:50:37.93)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-06-01 04:18:12 (running for 04:50:42.95)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-06-01 04:18:18 (running for 04:50:47.98)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-06-01 04:18:23 (running for 04:50:53.00)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-06-01 04:18:28 (running for 04:50:58.02)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-06-01 04:18:33 (running for 04:51:03.04)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-06-01 04:18:38 (running for 04:51:08.06)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-06-01 04:18:43 (running for 04:51:13.08)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-06-01 04:18:48 (running for 04:51:18.10)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-06-01 04:18:53 (running for 04:51:23.13)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-06-01 04:18:58 (running for 04:51:28.15)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-06-01 04:19:03 (running for 04:51:33.17)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-06-01 04:19:08 (running for 04:51:38.19)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-06-01 04:19:13 (running for 04:51:43.21)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-06-01 04:19:18 (running for 04:51:48.24)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-06-01 04:19:23 (running for 04:51:53.26)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-06-01 04:19:28 (running for 04:51:58.28)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-06-01 04:19:33 (running for 04:52:03.30)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-06-01 04:19:38 (running for 04:52:08.33)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-06-01 04:19:43 (running for 04:52:13.35)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-06-01 04:19:48 (running for 04:52:18.38)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-06-01 04:19:53 (running for 04:52:23.40)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-06-01 04:19:58 (running for 04:52:28.42)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-06-01 04:20:03 (running for 04:52:33.45)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-06-01 04:20:08 (running for 04:52:38.47)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-06-01 04:20:13 (running for 04:52:43.49)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-06-01 04:20:18 (running for 04:52:48.51)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-06-01 04:20:23 (running for 04:52:53.53)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-06-01 04:20:28 (running for 04:52:58.56)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-06-01 04:20:33 (running for 04:53:03.58)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-06-01 04:20:38 (running for 04:53:08.60)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-06-01 04:20:43 (running for 04:53:13.62)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-06-01 04:20:48 (running for 04:53:18.64)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-06-01 04:20:53 (running for 04:53:23.66)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-06-01 04:20:58 (running for 04:53:28.69)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-06-01 04:21:03 (running for 04:53:33.71)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-06-01 04:21:08 (running for 04:53:38.73)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# == Status ==
# Current time: 2026-06-01 04:21:13 (running for 04:53:43.75)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 RUNNING)
#
#
# (RayTrainWorker pid=1788904) Epoch 5: loss = 0.01285
# (RayTrainWorker pid=1788904) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/ysuh2/ray_results/TorchTrainer_2026-05-31_23-27-29/TorchTrainer_f73b3_00000_0_2026-05-31_23-27-30/checkpoint_000004)
# 2026-06-01 04:21:17,394	INFO tune.py:1009 -- Wrote the latest version of all result files and experiment state to '/home/ysuh2/ray_results/TorchTrainer_2026-05-31_23-27-29' in 0.0354s.
# 2026-06-01 04:21:17,397	INFO tune.py:1041 -- Total run time: 17627.39 seconds (17627.33 seconds for the tuning loop).
# == Status ==
# Current time: 2026-06-01 04:21:17 (running for 04:53:47.37)
# Using FIFO scheduling algorithm.
# Logical resource usage: 5.0/8 CPUs, 0/0 GPUs
# Result logdir: /tmp/ray/ray/session_2026-05-31_23-26-36_745959_1765005/artifacts/2026-05-31_23-27-30/TorchTrainer_2026-05-31_23-27-29/driver_artifacts
# Number of trials: 1/1 (1 TERMINATED)
#
#
# --- Training Execution Finished successfully! ---
#
# --- Running Inference Setup ---
# Predicted P Wave Arrival Time: 8.99s (Index: 899)
# Predicted S Wave Arrival Time: 11.35s (Index: 1135)
#
# --- Running Full Test Dataset Evaluation ---
# --------------------------------------------------
# Final Training Loss: 0.01285
# Final Average Test Loss: 0.01275
# Evaluated on 16832 total samples.
# --------------------------------------------------
